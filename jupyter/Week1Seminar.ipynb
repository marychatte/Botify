# %% [markdown]
# # Week 1 Seminar
#
# A/B experiment analysis

# %%
from collections import namedtuple

import pandas as pd
import numpy as np
import scipy.stats as ss

import matplotlib.pyplot as plt

pd.set_option("display.precision", 3)

# %matplotlib inline

# %%
experiment = "RECOMMENDERS"

# %%
data = pd.read_json("/Users/n.anokhin/Desktop/data.json", lines=True)
data["treatment"] = data["experiments"].map(lambda experiments: experiments[experiment])

# %% [markdown]
# ## Visualize sessions

# %%
Session = namedtuple("Session", ["timestamp", "tracks", "time", "latency"])

def sessionize(user_data):
    sessions = []
    session = None
    for _, row in user_data.sort_values("timestamp").iterrows():
        if session is None:
            session = Session(row["timestamp"], 0, 0, 0)
        
        session = session._replace(
            tracks = session.tracks + 1, 
            time = session.time + row["time"],
            latency = session.latency + row["latency"] * 1000,
        )
        
        if row["message"] == "last":
            sessions.append(session._asdict())
            session = None
    return sessions

# %%
sessions = (
    data
    .groupby(["user", "treatment"])
    .apply(sessionize)
    .explode()
    .apply(pd.Series)
)

# %%
figure, ax = plt.subplots(figsize=(15, 5))
for treatment, treatment_sessions in sessions.groupby("treatment"):
    reindexed_treatment_sessions = treatment_sessions.sort_values("timestamp").reset_index()
    ax.plot(reindexed_treatment_sessions.index, reindexed_treatment_sessions["tracks"], label=treatment)
ax.legend()
pass

# %%
figure, ax = plt.subplots(figsize=(15, 5))
for treatment, treatment_sessions in sessions.groupby("treatment"):
    reindexed_treatment_sessions = treatment_sessions.sort_values("timestamp").reset_index()
    ax.plot(reindexed_treatment_sessions.index, reindexed_treatment_sessions["time"], label=treatment)
ax.legend()
pass

# %% [markdown]
# ## Analyze the experiment

# %%
user_level_data = (
  sessions
    .reset_index()
    .groupby(["user", "treatment"])
    .agg(
        {
            "timestamp": "count",
            "tracks": "sum",
            "time": "sum",
            "latency": "sum"
        }
    )
)

user_level_data["sessions"] = user_level_data["timestamp"]
user_level_data["mean_request_latency"] = user_level_data["latency"] / user_level_data["tracks"]
user_level_data["mean_tracks_per_session"] = user_level_data["tracks"] / user_level_data["sessions"]
user_level_data["mean_time_per_session"] = user_level_data["time"] / user_level_data["sessions"]

metrics = [
    "time", 
    "sessions", 
    "mean_request_latency", 
    "mean_tracks_per_session", 
    "mean_time_per_session"
]

user_level_metrics = user_level_data[metrics].copy().reset_index()

# %% [raw]
# recommendations = pd.read_json("/Users/n.anokhin/Desktop/recommendations.json", lines=True)
# users = set(recommendations["user"].values)
# user_with_recs_level_metrics = user_level_metrics[user_level_metrics["user"].isin(users)].copy()

# %%
treatment_level_metrics = (
    user_level_metrics
    .groupby("treatment")[metrics]
    .agg(["count", "mean", "var"])
)

# %%
def dof(n_0, n_1, s2_0, s2_1):
    numerator = (s2_0 / n_0 + s2_1 / n_1) * (s2_0 / n_0 + s2_1 / n_1)
    denominator = s2_0 * s2_0 / n_0 / n_0 / (n_0 - 1) + s2_1 * s2_1 / n_1 / n_1 / (n_1 - 1)
    return numerator / denominator


def ci(n_0, n_1, s2_0, s2_1, alpha=0.05):
    return ss.t.ppf(1 - alpha/2, dof(n_0, n_1, s2_0, s2_1)) * np.sqrt(s2_0 / n_0 + s2_1 / n_1)


effects = []

control = [data for treatment, data in treatment_level_metrics.iterrows() if treatment == "C"][0]

for treatment, row in treatment_level_metrics.iterrows():
    if treatment == "C":
        continue
    
    for metric in metrics:
        control_mean = control[metric]["mean"]
        treatment_mean = row[metric]["mean"]
        
        effect = treatment_mean - control_mean
        conf_int = ci(
            control[metric]["count"],
            row[metric]["count"],
            control[metric]["var"],
            row[metric]["var"],
        )
        effects.append({
            "treatment": treatment,
            "metric": metric,
            "control_mean": control_mean,
            "treatment_mean": treatment_mean,
            "effect": effect / control_mean * 100,
            "lower": (effect - conf_int) / control_mean * 100,
            "upper": (effect + conf_int) / control_mean * 100,
            "significant": (effect + conf_int) * (effect - conf_int) > 0
        })

# %%
def color(value):
    return 'color:red;' if value < 0 else 'color:green;'

def background(value):
    return 'color:white;background-color:green' if value else 'color:white;background-color:red'
        

(
    pd.DataFrame(effects)[[
        "treatment", 
        "metric",
        "effect", 
        "upper", 
        "lower", 
        "control_mean", 
        "treatment_mean",
        "significant"
    ]]
    .sort_values("treatment", ascending=False)
    .style
    .applymap(color, subset=["effect", "upper", "lower"])
    .applymap(background, subset=["significant"])
)
# Out:
# <style type="text/css">
# #T_d1880_row0_col2, #T_d1880_row0_col3, #T_d1880_row0_col4, #T_d1880_row1_col2, #T_d1880_row1_col3, #T_d1880_row1_col4, #T_d1880_row3_col2, #T_d1880_row3_col3, #T_d1880_row4_col2, #T_d1880_row4_col3, #T_d1880_row4_col4, #T_d1880_row5_col3, #T_d1880_row6_col2, #T_d1880_row6_col3, #T_d1880_row6_col4, #T_d1880_row7_col2, #T_d1880_row7_col3, #T_d1880_row7_col4, #T_d1880_row8_col2, #T_d1880_row8_col3, #T_d1880_row8_col4, #T_d1880_row9_col2, #T_d1880_row9_col3, #T_d1880_row9_col4, #T_d1880_row10_col2, #T_d1880_row10_col3, #T_d1880_row10_col4, #T_d1880_row11_col2, #T_d1880_row11_col3, #T_d1880_row11_col4, #T_d1880_row12_col2, #T_d1880_row12_col3, #T_d1880_row12_col4, #T_d1880_row13_col3, #T_d1880_row14_col2, #T_d1880_row14_col3, #T_d1880_row14_col4, #T_d1880_row15_col3, #T_d1880_row16_col2, #T_d1880_row16_col3, #T_d1880_row16_col4, #T_d1880_row17_col2, #T_d1880_row17_col3, #T_d1880_row17_col4, #T_d1880_row18_col2, #T_d1880_row18_col3, #T_d1880_row18_col4, #T_d1880_row19_col2, #T_d1880_row19_col3, #T_d1880_row19_col4 {
#   color: green;
# }
# #T_d1880_row0_col7, #T_d1880_row1_col7, #T_d1880_row2_col7, #T_d1880_row4_col7, #T_d1880_row6_col7, #T_d1880_row7_col7, #T_d1880_row8_col7, #T_d1880_row9_col7, #T_d1880_row10_col7, #T_d1880_row11_col7, #T_d1880_row12_col7, #T_d1880_row14_col7, #T_d1880_row16_col7, #T_d1880_row17_col7, #T_d1880_row18_col7, #T_d1880_row19_col7 {
#   color: white;
#   background-color: green;
# }
# #T_d1880_row2_col2, #T_d1880_row2_col3, #T_d1880_row2_col4, #T_d1880_row3_col4, #T_d1880_row5_col2, #T_d1880_row5_col4, #T_d1880_row13_col2, #T_d1880_row13_col4, #T_d1880_row15_col2, #T_d1880_row15_col4 {
#   color: red;
# }
# #T_d1880_row3_col7, #T_d1880_row5_col7, #T_d1880_row13_col7, #T_d1880_row15_col7 {
#   color: white;
#   background-color: red;
# }
# </style>
# <table id="T_d1880_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >treatment</th>
#       <th class="col_heading level0 col1" >metric</th>
#       <th class="col_heading level0 col2" >effect</th>
#       <th class="col_heading level0 col3" >upper</th>
#       <th class="col_heading level0 col4" >lower</th>
#       <th class="col_heading level0 col5" >control_mean</th>
#       <th class="col_heading level0 col6" >treatment_mean</th>
#       <th class="col_heading level0 col7" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1880_level0_row0" class="row_heading level0 row0" >19</th>
#       <td id="T_d1880_row0_col0" class="data row0 col0" >T4</td>
#       <td id="T_d1880_row0_col1" class="data row0 col1" >mean_time_per_session</td>
#       <td id="T_d1880_row0_col2" class="data row0 col2" >57.666</td>
#       <td id="T_d1880_row0_col3" class="data row0 col3" >69.369</td>
#       <td id="T_d1880_row0_col4" class="data row0 col4" >45.963</td>
#       <td id="T_d1880_row0_col5" class="data row0 col5" >2.091</td>
#       <td id="T_d1880_row0_col6" class="data row0 col6" >3.296</td>
#       <td id="T_d1880_row0_col7" class="data row0 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d1880_level0_row1" class="row_heading level0 row1" >18</th>
#       <td id="T_d1880_row1_col0" class="data row1 col0" >T4</td>
#       <td id="T_d1880_row1_col1" class="data row1 col1" >mean_tracks_per_session</td>
#       <td id="T_d1880_row1_col2" class="data row1 col2" >17.546</td>
#       <td id="T_d1880_row1_col3" class="data row1 col3" >21.123</td>
#       <td id="T_d1880_row1_col4" class="data row1 col4" >13.969</td>
#       <td id="T_d1880_row1_col5" class="data row1 col5" >7.068</td>
#       <td id="T_d1880_row1_col6" class="data row1 col6" >8.308</td>
#       <td id="T_d1880_row1_col7" class="data row1 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d1880_level0_row2" class="row_heading level0 row2" >17</th>
#       <td id="T_d1880_row2_col0" class="data row2 col0" >T4</td>
#       <td id="T_d1880_row2_col1" class="data row2 col1" >mean_request_latency</td>
#       <td id="T_d1880_row2_col2" class="data row2 col2" >-44.850</td>
#       <td id="T_d1880_row2_col3" class="data row2 col3" >-43.986</td>
#       <td id="T_d1880_row2_col4" class="data row2 col4" >-45.714</td>
#       <td id="T_d1880_row2_col5" class="data row2 col5" >0.662</td>
#       <td id="T_d1880_row2_col6" class="data row2 col6" >0.365</td>
#       <td id="T_d1880_row2_col7" class="data row2 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d1880_level0_row3" class="row_heading level0 row3" >16</th>
#       <td id="T_d1880_row3_col0" class="data row3 col0" >T4</td>
#       <td id="T_d1880_row3_col1" class="data row3 col1" >sessions</td>
#       <td id="T_d1880_row3_col2" class="data row3 col2" >1.396</td>
#       <td id="T_d1880_row3_col3" class="data row3 col3" >5.693</td>
#       <td id="T_d1880_row3_col4" class="data row3 col4" >-2.901</td>
#       <td id="T_d1880_row3_col5" class="data row3 col5" >1.286</td>
#       <td id="T_d1880_row3_col6" class="data row3 col6" >1.303</td>
#       <td id="T_d1880_row3_col7" class="data row3 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1880_level0_row4" class="row_heading level0 row4" >15</th>
#       <td id="T_d1880_row4_col0" class="data row4 col0" >T4</td>
#       <td id="T_d1880_row4_col1" class="data row4 col1" >time</td>
#       <td id="T_d1880_row4_col2" class="data row4 col2" >59.283</td>
#       <td id="T_d1880_row4_col3" class="data row4 col3" >72.166</td>
#       <td id="T_d1880_row4_col4" class="data row4 col4" >46.399</td>
#       <td id="T_d1880_row4_col5" class="data row4 col5" >2.671</td>
#       <td id="T_d1880_row4_col6" class="data row4 col6" >4.254</td>
#       <td id="T_d1880_row4_col7" class="data row4 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d1880_level0_row5" class="row_heading level0 row5" >11</th>
#       <td id="T_d1880_row5_col0" class="data row5 col0" >T3</td>
#       <td id="T_d1880_row5_col1" class="data row5 col1" >sessions</td>
#       <td id="T_d1880_row5_col2" class="data row5 col2" >-0.692</td>
#       <td id="T_d1880_row5_col3" class="data row5 col3" >3.500</td>
#       <td id="T_d1880_row5_col4" class="data row5 col4" >-4.884</td>
#       <td id="T_d1880_row5_col5" class="data row5 col5" >1.286</td>
#       <td id="T_d1880_row5_col6" class="data row5 col6" >1.277</td>
#       <td id="T_d1880_row5_col7" class="data row5 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1880_level0_row6" class="row_heading level0 row6" >14</th>
#       <td id="T_d1880_row6_col0" class="data row6 col0" >T3</td>
#       <td id="T_d1880_row6_col1" class="data row6 col1" >mean_time_per_session</td>
#       <td id="T_d1880_row6_col2" class="data row6 col2" >121.344</td>
#       <td id="T_d1880_row6_col3" class="data row6 col3" >129.268</td>
#       <td id="T_d1880_row6_col4" class="data row6 col4" >113.421</td>
#       <td id="T_d1880_row6_col5" class="data row6 col5" >2.091</td>
#       <td id="T_d1880_row6_col6" class="data row6 col6" >4.627</td>
#       <td id="T_d1880_row6_col7" class="data row6 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d1880_level0_row7" class="row_heading level0 row7" >13</th>
#       <td id="T_d1880_row7_col0" class="data row7 col0" >T3</td>
#       <td id="T_d1880_row7_col1" class="data row7 col1" >mean_tracks_per_session</td>
#       <td id="T_d1880_row7_col2" class="data row7 col2" >36.820</td>
#       <td id="T_d1880_row7_col3" class="data row7 col3" >39.601</td>
#       <td id="T_d1880_row7_col4" class="data row7 col4" >34.038</td>
#       <td id="T_d1880_row7_col5" class="data row7 col5" >7.068</td>
#       <td id="T_d1880_row7_col6" class="data row7 col6" >9.670</td>
#       <td id="T_d1880_row7_col7" class="data row7 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d1880_level0_row8" class="row_heading level0 row8" >12</th>
#       <td id="T_d1880_row8_col0" class="data row8 col0" >T3</td>
#       <td id="T_d1880_row8_col1" class="data row8 col1" >mean_request_latency</td>
#       <td id="T_d1880_row8_col2" class="data row8 col2" >56.705</td>
#       <td id="T_d1880_row8_col3" class="data row8 col3" >57.887</td>
#       <td id="T_d1880_row8_col4" class="data row8 col4" >
